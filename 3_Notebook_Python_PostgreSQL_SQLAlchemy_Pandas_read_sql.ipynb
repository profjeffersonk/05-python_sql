# %% [markdown]
# # Pandas + PostgreSQL
#
# Exemplo simples mostrando como trazer dados do **PostgreSQL diretamente para um DataFrame Pandas** usando `pd.read_sql()`.
#
# ### Fluxo
#
# `PostgreSQL → Pandas DataFrame`

# %% [markdown]
# ## 1. Bibliotecas
#
# Vamos utilizar:
#
# - **Pandas** → trabalhar com os dados em `DataFrame`
# - **SQLAlchemy** → criar a conexão utilizada pelo Pandas para acessar o PostgreSQL
#
# Se necessário:
#
# ```bash
# pip install pandas sqlalchemy psycopg2-binary
# ```

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# %% [markdown]
# ## 2. Conexão com PostgreSQL
#
# Criamos um **Engine** do SQLAlchemy.
#
# O objetivo aqui não é estudar SQLAlchemy ORM. Ele está sendo usado apenas como a conexão que o Pandas utilizará para acessar o PostgreSQL.
#
# > ⚠️ Substitua os dados pelos dados do seu ambiente.

# %%
engine = create_engine(
    "postgresql+psycopg2://postgres:postgres@localhost:5432/loja_brasil"
)

print("Conexão configurada!")
# Out:
# Conexão configurada!

# %% [markdown]
# ## 3. `pd.read_sql()`
#
# Agora podemos escrever uma consulta SQL e passar o `engine` para o Pandas.
#
# O resultado já será um **DataFrame**.
#
# Sem precisar fazer manualmente `cursor()`, `execute()`, `fetchall()` e `pd.DataFrame()`.

# %%
df_clientes = pd.read_sql(
    "SELECT * FROM cadastro.clientes;",
    engine
)

df_clientes
# Out:
#     id_cliente                  nome                        email  \
# 0            2  Bruno Henrique Souza        bruno.souza@email.com
# 1            3      Camila Rodrigues   camila.rodrigues@email.com
# 2            4       Daniel Oliveira    daniel.oliveira@email.com
# 3            5     Eduarda Fernandes  eduarda.fernandes@email.com
# 4            6        Felipe Almeida     felipe.almeida@email.com
# 5            7        Gabriela Costa     gabriela.costa@email.com
# 6            8      Henrique Martins   henrique.martins@email.com
# 7            9        Isabela Santos     isabela.santos@email.com
# 8           10       João Pedro Lima          joao.lima@email.com
# 9           11          Karina Souza       karina.souza@email.com
# 10          12         Lucas Pereira      lucas.pereira@email.com
# 11          13         Mariana Alves      mariana.alves@email.com
# 12          14         Natália Rocha      natalia.rocha@email.com
# 13          15        Otávio Ribeiro     otavio.ribeiro@email.com
# 14          16       Patrícia Mendes    patricia.mendes@email.com
# 15          17          Rafael Gomes       rafael.gomes@email.com
# 16          18      Sabrina Teixeira   sabrina.teixeira@email.com
# 17          19          Thiago Nunes       thiago.nunes@email.com
# 18          20       Vanessa Cardoso    vanessa.cardoso@email.com
# 19           1     Ana Paula Martins        ana.martins@email.com
# 20          24             Ana Maria          ana.maria@email.com
# 21          25             Ana Souza          ana.souza@email.com
# 22          26           Carlos Lima        carlos.lima@email.com
# 23          27         João da Silva         joao.silva@email.com
#
#                 cidade estado data_cadastro  ativo
# 0             Pomerode     SC    2025-01-16   True
# 1            Joinville     SC    2025-01-27   True
# 2               Itajaí     SC    2025-02-07   True
# 3        Florianópolis     SC    2025-02-18   True
# 4              Brusque     SC    2025-03-01   True
# 5             Blumenau     SC    2025-03-12   True
# 6       Jaraguá do Sul     SC    2025-03-23   True
# 7           Rio do Sul     SC    2025-04-03   True
# 8                Timbó     SC    2025-04-14   True
# 9               Gaspar     SC    2025-04-25   True
# 10             Indaial     SC    2025-05-06   True
# 11            Blumenau     SC    2025-05-17   True
# 12            São José     SC    2025-05-28   True
# 13             Chapecó     SC    2025-06-08   True
# 14            Blumenau     SC    2025-06-19   True
# 15            Pomerode     SC    2025-06-30   True
# 16              Itajaí     SC    2025-07-11   True
# 17  Balneário Camboriú     SC    2025-07-22   True
# 18             Brusque     SC    2025-08-02   True
# 19       Florianópolis     SC    2025-01-05   True
# 20              Itajaí     SC    2026-09-09   True
# 21            Pomerode     SC    2026-09-09   True
# 22           Joinville     SC    2026-09-09   True
# 23            Criciúma     SC    2026-09-09   True

# %% [markdown]
# ## 4. SELECT com filtro
#
# Podemos continuar utilizando SQL normalmente.

# %%
df_blumenau = pd.read_sql(
    """
    SELECT id_cliente, nome, cidade, email
    FROM cadastro.clientes
    WHERE cidade = 'Blumenau';
    """,
    engine
)

df_blumenau
# Out:
#    id_cliente             nome    cidade                      email
# 0           7   Gabriela Costa  Blumenau   gabriela.costa@email.com
# 1          13    Mariana Alves  Blumenau    mariana.alves@email.com
# 2          16  Patrícia Mendes  Blumenau  patricia.mendes@email.com

# %% [markdown]
# ## 5. SELECT + JOIN
#
# Também podemos executar consultas com `JOIN` e receber o resultado diretamente como DataFrame.

# %%
df_pedidos = pd.read_sql(
    """
    SELECT
        c.nome,
        p.id_pedido,
        p.data_pedido
    FROM cadastro.clientes AS c
    INNER JOIN vendas.pedidos AS p
        ON p.id_cliente = c.id_cliente;
    """,
    engine
)

df_pedidos.head()
# Out:
#                    nome  id_pedido data_pedido
# 0      Henrique Martins          1  2025-02-10
# 1        Otávio Ribeiro          2  2025-02-19
# 2  Bruno Henrique Souza          3  2025-02-28
# 3        Isabela Santos          4  2025-03-09
# 4       Patrícia Mendes          5  2025-03-18

# %% [markdown]
# ## 6. SELECT + GROUP BY
#
# Podemos utilizar funções de agregação no SQL e receber o resultado no Pandas.

# %%
df_resumo = pd.read_sql(
    """
    SELECT 
        cidade, 
        COUNT(*) AS quantidade_clientes 
    FROM cadastro.clientes 
    GROUP BY cidade;
    """,
    engine
)

df_resumo
# Out:
#                 cidade  quantidade_clientes
# 0             Blumenau                    3
# 1            Joinville                    2
# 2        Florianópolis                    2
# 3             Pomerode                    3
# 4              Chapecó                    1
# 5              Indaial                    1
# 6               Gaspar                    1
# 7   Balneário Camboriú                    1
# 8           Rio do Sul                    1
# 9               Itajaí                    3
# 10             Brusque                    2
# 11               Timbó                    1
# 12            São José                    1
# 13      Jaraguá do Sul                    1

# %% [markdown]
# ## 7. Depois disso, usamos Pandas
#
# Depois que os dados estão no DataFrame, podemos utilizar normalmente os recursos do Pandas.

# %%
df_resumo.sort_values(
    "quantidade_clientes",
    ascending=False
)
# Out:
#                 cidade  quantidade_clientes
# 0             Blumenau                    3
# 3             Pomerode                    3
# 9               Itajaí                    3
# 1            Joinville                    2
# 10             Brusque                    2
# 2        Florianópolis                    2
# 5              Indaial                    1
# 4              Chapecó                    1
# 7   Balneário Camboriú                    1
# 6               Gaspar                    1
# 8           Rio do Sul                    1
# 11               Timbó                    1
# 12            São José                    1
# 13      Jaraguá do Sul                    1

# %% [markdown]
# ## 8. Resumo
#
# ### Com Psycopg2
#
# ```text
# SQL
#  ↓
# cursor.execute()
#  ↓
# fetchall()
#  ↓
# pd.DataFrame()
# ```
#
# ### Com `pd.read_sql()`
#
# ```text
# SQL
#  ↓
# pd.read_sql()
#  ↓
# DataFrame
# ```
#
# > **`pd.read_sql()` simplifica o processo de trazer dados do PostgreSQL para o Pandas.**
#
# O SQL continua sendo escrito normalmente; a diferença é que o resultado já chega como um **DataFrame**.

# %% [markdown]
# ## 9. Inserindo registros no PostgreSQL

# %%
# Criando um DataFrame com novos clientes para inserir no banco de dados

df_novos_clientes = pd.DataFrame({
    "nome": ["João da Silva"],
    "cidade": ["Criciúma"],
    "estado": ["SC"],
    "email": ["joao.silva@email.com"]
})

# %%
df_novos_clientes
# Out:
#             nome    cidade estado                 email
# 0  João da Silva  Criciúma     SC  joao.silva@email.com

# %%
# Inserindo os novos clientes no banco de dados

df_novos_clientes.to_sql(
    "clientes", # Nome da tabela do banco de dados que receberá os dados
    con=engine, # Conexão com o banco de dados
    schema="cadastro", # Nome do schema do banco de dados
    if_exists="append", # Se a tabela já existir, os dados serão adicionados ao final
    index=False # Não incluir o índice do DataFrame como coluna na tabela do banco de dados
)

print("Registro adicionado com sucesso!")
# Out:
# Registro adicionado com sucesso!

# %%
df_teste = pd.read_sql(
    """
    SELECT * FROM cadastro.clientes
    ORDER BY id_cliente DESC
    LIMIT 5;
    """, con=engine
)

df_teste
# Out:
#    id_cliente             nome                      email     cidade estado  \
# 0          27    João da Silva       joao.silva@email.com  Bombinhas     SC
# 1          26      Carlos Lima      carlos.lima@email.com  Joinville     SC
# 2          25        Ana Souza        ana.souza@email.com   Pomerode     SC
# 3          24        Ana Maria        ana.maria@email.com     Itajaí     SC
# 4          20  Vanessa Cardoso  vanessa.cardoso@email.com    Brusque     SC
#
#   data_cadastro  ativo
# 0    2026-09-09   True
# 1    2026-09-09   True
# 2    2026-09-09   True
# 3    2026-09-09   True
# 4    2025-08-02   True

# %%
df_teste = df_clientes.tail()

# %%
df_teste
# Out:
#     id_cliente               nome                  email         cidade  \
# 19           1  Ana Paula Martins  ana.martins@email.com  Florianópolis
# 20          24          Ana Maria    ana.maria@email.com         Itajaí
# 21          25          Ana Souza    ana.souza@email.com       Pomerode
# 22          26        Carlos Lima  carlos.lima@email.com      Joinville
# 23          27      João da Silva   joao.silva@email.com       Criciúma
#
#    estado data_cadastro  ativo
# 19     SC    2025-01-05   True
# 20     SC    2026-09-09   True
# 21     SC    2026-09-09   True
# 22     SC    2026-09-09   True
# 23     SC    2026-09-09   True

# %%
with engine.begin() as conn:
    conn.execute(
        text(
            """
            UPDATE cadastro.clientes
            SET cidade = :cidade
            WHERE email = :email;
            """
        ),
        {
            "cidade": "Bombinhas",
            "email": "joao.silva@email.com"
        }
    )
